# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load dataset
ratings = pd.read_csv("../ratings.csv")
movies = pd.read_csv("../movies.csv")

print("Ratings shape:", ratings.shape)
print("Movies shape:", movies.shape)
ratings.head()
# Out:
# 2025-10-17 18:29:17.729447: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-10-17 18:29:17.752262: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-17 18:29:18.844098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Check and clean data
print("Missing values in ratings:\n", ratings.isnull().sum())
ratings = ratings.drop_duplicates()

# Convert timestamp
if 'timestamp' in ratings.columns:
    ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')

# Feature engineering
movie_stats = ratings.groupby('movieId')['rating'].agg(['count', 'mean']).reset_index()
movie_stats.rename(columns={'count':'num_ratings', 'mean':'avg_rating'}, inplace=True)
movie_stats = movie_stats.merge(movies[['movieId','title']], on='movieId', how='left')
movie_stats.head()
# Out:
# Missing values in ratings:
#  userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
#    movieId  num_ratings  avg_rating                               title
# 0        1          215    3.920930                    Toy Story (1995)
# 1        2          110    3.431818                      Jumanji (1995)
# 2        3           52    3.259615             Grumpier Old Men (1995)
# 3        4            7    2.357143            Waiting to Exhale (1995)
# 4        5           49    3.071429  Father of the Bride Part II (1995)

# %%
# Ratings distribution
plt.figure(figsize=(6,4))
sns.histplot(ratings['rating'], bins=5, kde=True, color='teal')
plt.title("Ratings Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# Average rating vs number of ratings
plt.figure(figsize=(6,4))
sns.scatterplot(x='num_ratings', y='avg_rating', data=movie_stats, alpha=0.6)
plt.title("Average Rating vs Number of Ratings per Movie")
plt.xlabel("Number of Ratings")
plt.ylabel("Average Rating")
plt.show()

# Top 10 most rated movies
top_movies = movie_stats.sort_values('num_ratings', ascending=False).head(10)
plt.figure(figsize=(8,4))
sns.barplot(y='title', x='num_ratings', data=top_movies, palette='viridis')
plt.title("Top 10 Most Rated Movies")
plt.xlabel("Number of Ratings")
plt.ylabel("Movie Title")
plt.show()
# Out:
# /tmp/ipykernel_757/3028635960.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='title', x='num_ratings', data=top_movies, palette='viridis')

# %%
# Encode userId and movieId
user_ids = ratings['userId'].unique()
movie_ids = ratings['movieId'].unique()
user2idx = {u:i for i,u in enumerate(user_ids)}
movie2idx = {m:i for i,m in enumerate(movie_ids)}

ratings['user_idx'] = ratings['userId'].map(user2idx)
ratings['movie_idx'] = ratings['movieId'].map(movie2idx)

n_users = len(user2idx)
n_movies = len(movie2idx)
print("Users:", n_users, "Movies:", n_movies)

# Train-test split
train, test = train_test_split(ratings, test_size=0.2, random_state=42)
x_train = [train['user_idx'].values, train['movie_idx'].values]
y_train = train['rating'].values
x_test = [test['user_idx'].values, test['movie_idx'].values]
y_test = test['rating'].values
# Out:
# Users: 610 Movies: 9724

# %%
def build_ncf_model(n_users, n_movies, emb_dim=50):
    user_input = keras.Input(shape=(1,))
    movie_input = keras.Input(shape=(1,))
    user_emb = layers.Embedding(n_users, emb_dim)(user_input)
    movie_emb = layers.Embedding(n_movies, emb_dim)(movie_input)

    user_vec = layers.Flatten()(user_emb)
    movie_vec = layers.Flatten()(movie_emb)

    x = layers.Concatenate()([user_vec, movie_vec])
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dense(32, activation='relu')(x)
    output = layers.Dense(1)(x)

    model = keras.Model([user_input, movie_input], output)
    model.compile(optimizer='adam', loss='mse', metrics=[keras.metrics.RootMeanSquaredError()])
    return model

model = build_ncf_model(n_users, n_movies)
model.summary()
# Out:
# 2025-10-17 18:29:24.202050: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 1, 50)     │     30,500 │ input_layer[0][0] │
# ...

# %%
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=10,
    batch_size=256,
    verbose=1
)
# Out:
# Epoch 1/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.8235 - root_mean_squared_error: 1.3504 - val_loss: 0.7944 - val_root_mean_squared_error: 0.8913
# Epoch 2/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.7125 - root_mean_squared_error: 0.8441 - val_loss: 0.7730 - val_root_mean_squared_error: 0.8792
# Epoch 3/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6625 - root_mean_squared_error: 0.8139 - val_loss: 0.7608 - val_root_mean_squared_error: 0.8722
# Epoch 4/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6169 - root_mean_squared_error: 0.7854 - val_loss: 0.7677 - val_root_mean_squared_error: 0.8762
# Epoch 5/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5661 - root_mean_squared_error: 0.7524 - val_loss: 0.7874 - val_root_mean_squared_error: 0.8874
# Epoch 6/10
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.5055 - root_mean_squared_error: 0.7110 - val_loss: 0.8392 - val_root_mean_squared_error: 0.9161
# Epoch 7/10
# ...

# %%
# Plot training and validation loss
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Training Progress (Loss)")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.legend()
plt.show()

# RMSE
plt.figure(figsize=(6,4))
plt.plot(history.history['root_mean_squared_error'], label='Train RMSE')
plt.plot(history.history['val_root_mean_squared_error'], label='Val RMSE')
plt.title("Training Progress (RMSE)")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.legend()
plt.show()

# %%
preds = model.predict(x_test).flatten()
errors = y_test - preds

rmse = np.sqrt(mean_squared_error(y_test, preds))
print(f"Test RMSE: {rmse:.4f}")

# Error distribution
plt.figure(figsize=(6,4))
sns.histplot(errors, bins=30, kde=True, color='crimson')
plt.title("Error Distribution (Actual - Predicted)")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.show()

# Actual vs Predicted
plt.figure(figsize=(6,4))
sns.scatterplot(x=y_test, y=preds, alpha=0.5)
plt.title("Actual vs Predicted Ratings")
plt.xlabel("Actual Ratings")
plt.ylabel("Predicted Ratings")
plt.show()
# Out:
# 631/631 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Test RMSE: 0.9499

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

preds = model.predict(x_test).flatten()
rmse = np.sqrt(mean_squared_error(y_test, preds))
print(f"Test RMSE: {rmse:.4f}")
# Out:
# 631/631 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Test RMSE: 0.9499

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Convert predicted and actual ratings to binary: 1 = liked, 0 = not liked
# Adjust the threshold as needed (3.5 or 4.0 are typical)
threshold = 3.5

y_true_binary = (y_test >= threshold).astype(int)
y_pred_binary = (preds >= threshold).astype(int)

# Calculate metrics
accuracy = accuracy_score(y_true_binary, y_pred_binary)
precision = precision_score(y_true_binary, y_pred_binary, zero_division=0)
recall = recall_score(y_true_binary, y_pred_binary, zero_division=0)
f1 = f1_score(y_true_binary, y_pred_binary, zero_division=0)

print("📊 Evaluation Metrics for NCF Model")
print(f"Overall Accuracy  : {accuracy:.4f}")
print(f"Overall Precision : {precision:.4f}")
print(f"Overall Recall    : {recall:.4f}")
print(f"Overall F1-Score  : {f1:.4f}")

# Optional – visualize metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
values = [accuracy, precision, recall, f1]

plt.figure(figsize=(6,4))
plt.bar(metrics, values, color=['skyblue', 'orange', 'green', 'crimson'])
plt.ylim(0, 1)
plt.title("Model Evaluation Metrics (Binary Recommendation)")
plt.ylabel("Score")
plt.show()
# Out:
# 📊 Evaluation Metrics for NCF Model
# Overall Accuracy  : 0.6828
# Overall Precision : 0.7852
# Overall Recall    : 0.6629
# Overall F1-Score  : 0.7189
